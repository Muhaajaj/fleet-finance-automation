# %%
# !pip -q install -r https://raw.githubusercontent.com/Muhaajaj/fleet-finance-automation/main/requirements.txt

# %%
# !git clone https://github.com/Muhaajaj/fleet-finance-automation.git
# %cd fleet-finance-automation

# %%
# !python src/fleet_reconcile.py \
  --fleet data/sample/fleet_online_sample.xlsx \
  --hr data/sample/personal_costcenters_sample.xlsx \
  --out-dir outputs \
  --exclude-pool

# %%
# !python src/invoice_export.py \
  --invoice data/sample/dkv_detail_sample.csv \
  --mapping outputs/fleet_mapping_refreshed.xlsx \
  --out outputs/booking_export.csv \
  --missing-out outputs/missing_costcenters.xlsx

# %%
# !ls -lah outputs
